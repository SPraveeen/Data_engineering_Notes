# %% [markdown]
# #### Given a large table with 3 columns (datetime, employee, customer_response), find the top 10 employees with the most phone numbers found in the customer_response column.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
