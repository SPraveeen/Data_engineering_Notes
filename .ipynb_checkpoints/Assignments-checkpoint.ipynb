# %%
import pandas as pd

# %%
s=pd.Series([1,2,3],index=[0,2,4])

# %%
s
# Out:
# 0    1
# 2    2
# 4    3
# dtype: int64

# %%
print(s.reindex(range(5),method='ffill'))
# Out:
# 0    1
# 1    1
# 2    2
# 3    2
# 4    3
# dtype: int64

# %%
# 2
df=pd.DataFrame({'A':[1,2],
                'B':[3,4]},index=['x','y'])
df
# Out:
#    A  B
# x  1  3
# y  2  4

# %%
print(df.loc['x':'y'])
# Out:
#    A  B
# x  1  3
# y  2  4

# %%
# 3
df=pd.DataFrame({'A':[1,2,3],'B':[4,5,6]})
df
# Out:
#    A  B
# 0  1  4
# 1  2  5
# 2  3  6

# %%
print(df.apply(lambda x:x.max()-x.min()))
# Out:
# A    2
# B    2
# dtype: int64

# %%
# 4
df=pd.DataFrame({'A':[1,1,2,2],
                'B':[10,20,30,40]})
print(df.groupby('A')['B'].transform('mean'))
# Out:
# 0    15.0
# 1    15.0
# 2    35.0
# 3    35.0
# Name: B, dtype: float64

# %%
#5
df = pd.DataFrame({'A':[1,2,None,3]}) 
print(df.dropna().reset_index(drop=True))
# Out:
#      A
# 0  1.0
# 1  2.0
# 2  3.0

# %%
#6
df['A'].sum()
# not as fast as this

df['A'].valuessum()
#faster
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_5180\411151480.py in ?()
#       1 #6
#       2 df['A'].sum()
#       3 # not as fast as this
#       4
# ----> 5 df['A'].valuessum()
#       6 #faster
#
# ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6295             and name not in self._accessors
#    6296             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#
# AttributeError: 'Series' object has no attribute 'valuessum'

# %%
#7
import matplotlib.pyplot as plt 
plt.plot([1,2,3],[4,5,6], label="line")
plt.legend(loc="best") 
plt.show()

# %%
# 8
import seaborn as sns 
df = pd.DataFrame({'A':[1,2,3,4],'B':[4,3,2,1]}) 
sns.lineplot(x='A', y='B', data=df)
# Out:
# <Axes: xlabel='A', ylabel='B'>

# %%
ig, ax = plt.subplots(2,1) 
ax[0].plot([1,2],[3,4]) 
ax[1].bar([1,2],[5,6]) 
plt.show()

# %%
f = pd.DataFrame({'A':[1,2,3], 'B':[3,2,1]}) 
df.plot(x='A', y='B', kind='bar')
# Out:
# <Axes: xlabel='A'>
